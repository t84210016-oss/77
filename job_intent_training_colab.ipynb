# %% [markdown]
# <a href="https://colab.research.google.com/github/t84210016-oss/77/blob/main/job_intent_training_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers datasets accelerate scikit-learn pandas torch

# %%
import pandas as pd
import torch
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)
from sklearn.metrics import accuracy_score, f1_score

# %%
URL = "https://raw.githubusercontent.com/t84210016-oss/77/refs/heads/main/posts_1000_diverse.csv"
df = pd.read_csv(URL)

label_map = {"job_offer": 1, "job_seeker": 0}
df["label"] = df["target"].map(label_map)

df = df[["post", "label"]]
df.head()
# Out:
#                                                 post  label
# 0  DataForge recrute un(e) stagiaire PFE Data Sci...      1
# 1  IBM is seeking a software engineer to join our...      1
# 2  Je m'appelle Amine  Ã©tudiant en 3Ã¨me annÃ©e ...      0
# 3  Oracle is looking for a cloud engineer to join...      1
# 4  Hello  my name is Yassine and I'm a web develo...      0

# %%
dataset = Dataset.from_pandas(df)

dataset = dataset.train_test_split(
    test_size=0.2,
    seed=42
)

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['post', 'label'],
#         num_rows: 722
#     })
#     test: Dataset({
#         features: ['post', 'label'],
#         num_rows: 181
#     })
# })

# %%
MODEL_NAME = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def tokenize(batch):
    return tokenizer(
        batch["post"],
        padding="max_length",
        truncation=True,
        max_length=128
    )

# %%
dataset = dataset.map(tokenize, batched=True)
dataset = dataset.remove_columns(["post"])
dataset.set_format("torch")

dataset
# Out:
# Map:   0%|          | 0/722 [00:00<?, ? examples/s]
# Map:   0%|          | 0/181 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 722
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 181
#     })
# })

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=2
)
# Out:
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = logits.argmax(axis=1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1": f1_score(labels, preds)
    }

# %%
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=10,
    weight_decay=0.01,
    logging_steps=50,
    load_best_model_at_end=True,
    report_to="none"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# /tmp/ipython-input-1592133508.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 15:15, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.002070</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.188400</td>
#       <td>0.000376</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001300</td>
#       <td>0.000228</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000500</td>
#       <td>0.000140</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000400</td>
#       <td>0.000124</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000300</td>
#       <td>0.000109</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000200</td>
#       <td>0.000112</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000200</td>
#       <td>0.000093</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000200</td>
#       <td>0.000091</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000200</td>
#       <td>0.000087</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=460, training_loss=0.020843357444265048, metrics={'train_runtime': 916.3691, 'train_samples_per_second': 7.879, 'train_steps_per_second': 0.502, 'total_flos': 474915454924800.0, 'train_loss': 0.020843357444265048, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='24' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 00:37]
#     </div>
# {'eval_loss': 8.731401612749323e-05,
#  'eval_accuracy': 1.0,
#  'eval_f1': 1.0,
#  'eval_runtime': 1.2115,
#  'eval_samples_per_second': 149.405,
#  'eval_steps_per_second': 9.905,
#  'epoch': 10.0}

# %%
def predict(text):
    # Detect device of the model (CPU or GPU)
    device = next(model.parameters()).device

    # Tokenize and move inputs to the same device as the model
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True).to(device)

    # Forward pass
    with torch.no_grad():
        outputs = model(**inputs)

    # Get probabilities and predicted label
    probs = torch.softmax(outputs.logits, dim=1)
    label = torch.argmax(probs).item()

    return "hiring" if label == 1 else "job_seeker"

# Test predictions
print(predict("Recherche développeur React pour startup"))
print(predict("Disponible pour un poste de data analyst"))
print(predict("Hiring backend engineer ASAP"))
# Out:
# hiring
# hiring
# hiring

# %%
trainer.save_model("job_intent_model")
tokenizer.save_pretrained("job_intent_model")
# Out:
# ('job_intent_model/tokenizer_config.json',
#  'job_intent_model/special_tokens_map.json',
#  'job_intent_model/sentencepiece.bpe.model',
#  'job_intent_model/added_tokens.json',
#  'job_intent_model/tokenizer.json')

# %%
# -----------------------------
# 1️⃣ Install packages
# -----------------------------
# !pip install -q transformers torch pandas requests

# -----------------------------
# 2️⃣ Imports
# -----------------------------
import pandas as pd
import requests
import torch
import json
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from google.colab import files  # for download

# -----------------------------
# 3️⃣ Read JSON from GitHub
# -----------------------------
url = "https://raw.githubusercontent.com/anan181991ba-glitch/000/refs/heads/main/linkedin_emails.json"
data = requests.get(url).json()

# Convert JSON to DataFrame
records = [{"email": email, **info} for email, info in data.items()]
df = pd.DataFrame(records)

# -----------------------------
# 4️⃣ Load your saved model
# -----------------------------
model_path = "job_intent_model"  # replace if different

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)
model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# -----------------------------
# 5️⃣ Define prediction function
# -----------------------------
def predict_intent(texts, batch_size=16):
    all_labels = []
    label_map = {0: "job_seeker", 1: "job_offer"}  # adjust if your training labels differ

    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        inputs = tokenizer(batch, padding=True, truncation=True, return_tensors="pt").to(device)
        with torch.no_grad():
            outputs = model(**inputs)
            preds = torch.argmax(outputs.logits, dim=-1)
            all_labels.extend([label_map[p.item()] for p in preds])
    return all_labels

# -----------------------------
# 6️⃣ Predict
# -----------------------------
posts = df["post_text"].tolist()
df["intent"] = predict_intent(posts)

print(df.head())

# -----------------------------
# 7️⃣ Save to CSV
# -----------------------------
csv_file = "linkedin_email_intent.csv"
df.to_csv(csv_file, index=False)
print(f"✅ Saved CSV: {csv_file}")

# -----------------------------
# 8️⃣ Merge predictions into original JSON
# -----------------------------
# This keeps the original structure and adds "intent"
for _, row in df.iterrows():
    email = row["email"]
    data[email]["intent"] = row["intent"]

# Save updated JSON
json_file = "linkedin_email_intent_full.json"
with open(json_file, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

print(f"✅ Saved JSON with full structure: {json_file}")

# Optional: show first 5 items
for k, v in list(data.items())[:5]:
    print(k, "->", v)

# -----------------------------
# 9️⃣ Download JSON automatically in Colab
# -----------------------------
files.download(json_file)
print("✅ JSON download should start automatically")
# Out:
# The tokenizer you are loading from 'job_intent_model' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
#                             email        keyword  \
# 0      abdelilah.benhrl@gmail.com  Stage PFE2026
# 1     charifachaqri2002@gmail.com  Stage PFE2026
# 2             m.habbi@outlook.com  Stage PFE2026
# 3  ressources-humaines@casanet.ma  Stage PFE2026
# 4           rh@bagile-systems.com  Stage PFE2026
#
#                                            post_text      intent
# 0  🎓 Recherche d’un stage de Projet de Fin d’Étud...  job_seeker
# 1  À la recherche d’un stage PFE en énergie & éne...  job_seeker
# 2  À la recherche d’un Stage de Fin d’Études (PFE...  job_seeker
# 3  🎓 Opportunité Stage PFE – Marketing | Février ...   job_offer
# 4  Salam cher réseau, \n\nOn cherche un(e) stagia...   job_offer
# ✅ Saved CSV: linkedin_email_intent.csv
# ✅ Saved JSON with full structure: linkedin_email_intent_full.json
# abdelilah.benhrl@gmail.com -> {'keyword': 'Stage PFE2026', 'post_text': '🎓 Recherche d’un stage de Projet de Fin d’Études (PFE)\n\nActuellement étudiant en Master en Conception et Simulation Numérique en Mécanique, je suis à la recherche d’un stage de Projet de Fin d’Études (PFE).\nMes domaines de compétences et d’intérêt incluent :\n\n– Conception mécanique\n– Simulation numérique et calcul par éléments finis\n– Analyse structurale\n\nRigoureux, motivé et doté d’un bon esprit d’analyse, je souhaite intégrer une entreprise ou un bureau d’études afin de contribuer à des projets techniques à forte valeur ajoutée tout en renforçant mes compétences.\n\n📍 Disponible à partir de février 2026\n📧 Contact : abdelilah.benhrl@gmail.com\n\n📩 Je reste ouvert à toute opportunité ou recommandation.\n\n\n\nhashtag\n#MechanicalEngineering \nhashtag\n#Simulation \nhashtag\n#NumericalAnalysis \nhashtag\n#FEA \nhashtag\n#FatigueAnalysis \nhashtag\n#EngineeringOpportunities \nhashtag\n#Innovation \nhashtag\n#emploi \nhashtag\n#Mécanique \nhashtag\n#Conception \nhashtag\n#Automobile \nhashtag\n#Aéronautique \nhashtag\n#StagePFE \nhashtag\n#PFE2026 \nhashtag\n#Ingénierie', 'intent': 'job_seeker'}
# charifachaqri2002@gmail.com -> {'keyword': 'Stage PFE2026', 'post_text': 'À la recherche d’un stage PFE en énergie & énergies renouvelables – disponible à partir de mars 2026\nHello LinkedIn ! \nJe suis Charifa Chaqri, ingénieure en Génie des Systèmes Électriques et actuellement en Master 2 Énergie électrique, environnement et fiabilité des systèmes à Montpellier. Passionnée par l’énergie et les énergies renouvelables, je suis à la recherche d’un final year internship (PFE) partout en France.\nJe suis spécialisée dans :\n🔹 Énergie électrique & systèmes industriels\n🔹 Énergies renouvelables (photovoltaïque, optimisation énergétique)\n🔹 Études, simulation et dimensionnement\n🔹 Fiabilité et efficacité énergétique\n➡️ Projets & réalisations : convertisseur BOOST, installations photovoltaïques, hacheurs, optimisation MPPT, banc d’essai moteur synchrone, systèmes d’éclairage\n➡️ Logiciels & outils : ETAP, PSIM, MATLAB, Dialux, PVSyst, AutoCAD, Proteus ISIS, Excel VBA\n➡️ Dimensionnement & notes de calcul : éclairage, groupes électrogènes, câbles, protections, UPS 48V\n➡️ Fiabilité & efficacité énergétique : analyse et optimisation de systèmes industriels\nMotivée, curieuse et toujours prête à relever de nouveaux challenges, I’m eager to contribute to innovative projects in the energy and renewable sectors \n📩 Pour me contacter directement : charifachaqri2002@gmail.com\nOuverte à toute opportunité ou échange ! Thanks in advance to my network for shares and connections \n\nhashtag\n#StagePFE \nhashtag\n#PFE2026 \nhashtag\n#ÉnergiesRenouvelables \nhashtag\n#Energy \nhashtag\n#ElectricalSystems \nhashtag\n#Innovation \nhashtag\n#Photovoltaic \nhashtag\n#Simulation \nhashtag\n#IndustrialProjects \nhashtag\n#EnergyEfficiency \nhashtag\n#IngénieurÉnergie \nhashtag\n#RenewableEnergy \nhashtag\n#ElectricalEngineering \nhashtag\n#Engineering \nhashtag\n#ProjetIndustriel', 'intent': 'job_seeker'}
# m.habbi@outlook.com -> {'keyword': 'Stage PFE2026', 'post_text': 'À la recherche d’un Stage de Fin d’Études (PFE) – Ingénieur Systèmes Embarqués / FPGA (VHDL)\n\nBonjour à tous,\nJe suis Mohammed HABBI, étudiant en 3ᵉ année à l’ENSEM Nancy (ingénierie des systèmes et automatisation), et je suis actuellement à la recherche d’un stage de fin d’études orienté conception numérique et développement sur FPGA.\n\nJe recherche un stage de 6 mois à partir de mars 2026.\nPassionné par le hardware design et le développement bas niveau, je souhaite intégrer une équipe où je pourrai contribuer à des projets de conception, d’implémentation et de validation sur cartes FPGA, notamment en VHDL.\n\nMon profil polyvalent me permet d’intervenir sur des sujets complets, de la conception à la vérification :\n-Conception VHDL : design de modules, interfaces, intégration.\n-Simulation & vérification : testbenches, debug, validation fonctionnelle (ModelSim/Questa selon environnement).\n-FPGA & systèmes embarqués : contraintes temporelles, intégration sur carte, interfaces (SPI/I²C/UART selon besoin), documentation et mise au point.\n\nSi vous avez une opportunité de stage en conception FPGA, validation/verification, ou systèmes embarqués à me recommander (R&D, bureau d’études, ou équipe hardware/software), je serais ravi d’échanger.\n\nEmail : m.habbi@outlook.com\nMerci pour votre lecture et vos partages !\n\n\nhashtag\n#Stage \nhashtag\n#PFE2026 \nhashtag\n#FPGA \nhashtag\n#VHDL \nhashtag\n#DigitalDesign \nhashtag\n#RTL \nhashtag\n#HardwareDesign \nhashtag\n#EmbeddedSystems \nhashtag\n#Verification', 'intent': 'job_seeker'}
# ressources-humaines@casanet.ma -> {'keyword': 'Stage PFE2026', 'post_text': '🎓 Opportunité Stage PFE – Marketing | Février 2026\n\nJe suis à la recherche de stagiaires PFE en Marketing motivé(e)s pour contribuer à des projets concrets liés au marketing digital, à la data et au branding.\n🎯 Profil recherché :\nÉtudiant(e) en Marketing / Communication / Management\nIntérêt pour le digital, la data ou la communication\nEsprit créatif, tech-savvy et à l’aise à l’oral\nEnvie d’apprendre et de s’impliquer sur des projets à impact\n\n📅 Démarrage : février 2026\n📩 Candidature: CV en message privé ou à l’adresse suivante :\n ressources-humaines@casanet.ma\n\nMerci de liker ou partager pour plus de visibilité 🙏\n\n\n\n\nhashtag\n#StagePFE \nhashtag\n#Marketing \nhashtag\n#MarketingDigital \nhashtag\n#Branding \nhashtag\n#DataMarketing \nhashtag\n#PFE2026', 'intent': 'job_offer'}
# rh@bagile-systems.com -> {'keyword': 'Stage PFE2026', 'post_text': 'Salam cher réseau, \n\nOn cherche un(e) stagiaire PFE pour nous rejoindre à B-AGILE et travailler sur des projets concrets, dans une bonne ambiance et un cadre idéal pour apprendre.\n\nConcrètement, tu vas :\n\n- Participer et assister à l’analyse des besoins métiers (Transport, Maintenance, Achats, Stocks…).\n\n- Contribuer à la rédaction de cahiers des charges fonctionnels.\n\n- Participer au paramétrage et aux tests.\n\n- Faire le lien entre les équipes métier et techniques.\n\n👉 Profil recherché :\nOn cherche quelqu’un de motivé, sérieux et intéressé par les systèmes d’information et la logistique.\n\n📍 PFE 2026 : CASABLANCA\n📩 Intéressé(e) ? Envoyez votre CV à : rh@bagile-systems.com\n\n\n\nhashtag\n#PFE \nhashtag\n#PFE2026 \nhashtag\n#Stage \nhashtag\n#TMS \nhashtag\n#GMAO \nhashtag\n#Digitalisation \nhashtag\n#STOCK \nhashtag\n#WMS \nhashtag\n#BAGILE \nhashtag\n#ERP', 'intent': 'job_offer'}
# ✅ JSON download should start automatically
